# %%
import pandas as pd
import numpy as np

# %%
listname1 = input("Please select first file to compare: ")
list1 = pd.read_csv(listname1+".csv")
listname2 = input("Please select second file to compare: ")
list2 = pd.read_csv(listname2+".csv")
# Out:
# Please select first file to compare: 2003_split
# Please select second file to compare: 2008_split

# %%
indexcount = 0
for index, row in list1.iterrows():
    print(list1['First Name'].iloc[indexcount], list1['Last Name'].iloc[indexcount])
    match = (list2["Last Name"].str.match(list1['Last Name'].iloc[indexcount])).bool
#    if match == False:
    print(match)    
    indexcount += 1
# Out:
# ED SR WUJCIK
# <bound method NDFrame.bool of 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# Name: Last Name, dtype: bool>
# ALEX MIKULSKI
# <bound method NDFrame.bool of 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# ...
